# %%
suppressPackageStartupMessages({
    # Tidyverse
    library('dplyr')
    library('readr')
    library('purrr')
    library('glue')
    library('stringr')
    library('tibble')

    # Bioinformatics - Helpers
    library('biomaRt')  # ID-mapping
    library('tximport')  # For smooth kallisto imports

    # Bioinformatics - Analyses tools
    library('estimate')  # http://bioinformatics.mdanderson.org/estimate/
    library('xCell')  # https://github.com/dviraran/xCell
    library('MCPcounter')
    # ... and we have CIBERSORT as a Java/R hybrid application
})

# Show traceback on runtime error!
options(error=function() { traceback(2); q() })

# Other helpers
head3 <- function(x, ...) { head(x, n=3, ...) }

## simple wrapper for running shell commands
shell <- function(cmdargs, command="bash") {
    # We need the full path to the main program
    command_path <- Sys.which(command)
    system(glue("{command_path} {cmdargs}"))
}

# %%
get_expression_data <- function(tmpdir) {
    expression_name <- glue("{tmpdir}/gene-expression-matrix.csv")
    if (file.exists(expression_name)) {
        return(read_csv(expression_name) %>%
                    data.frame() %>%
                    tibble::column_to_rownames("Gene_symbol"))
    }

    mart <- useMart(biomart="ENSEMBL_MART_ENSEMBL", dataset="hsapiens_gene_ensembl", host="ensembl.org")
    t2g <- getBM(attributes=c("ensembl_transcript_id", "external_gene_name"), mart=mart)
    t2g <- dplyr::rename(t2g, target_id=ensembl_transcript_id, ext_gene=external_gene_name)
    head(t2g)

    kallisto_files <- dir('data', recursive=TRUE, full.names=TRUE, pattern="*.tsv")

    # Import and reduce
    txi <- tximport(kallisto_files, type="kallisto", tx2gene=t2g)
    expression_data <- txi$counts

    # RCC and Kallisto names are redundant and can be omitted
    # Makes columns patient identifiers
    colnames(expression_data) <- kallisto_files %>% 
                                    str_replace("-kallisto/abundance.tsv", "") %>%
                                    str_replace("data/", "") %>%
                                    str_replace_all("-|_", ".")
    head3(expression_data)

    expression_data %>%
        as.data.frame %>%
        tibble::rownames_to_column("Gene_symbol") %>%
        write_csv(path=expression_name)
}

# %%
run_cibersort <- function(expression_data, tmpdir) {
    cibersort_home_dir <- glue("{tmpdir}/cibersort")

    lm22_path <- glue("{cibersort_home_dir}/LM22.txt")
    lm22_df <- read_tsv(lm22_path)
    head3(lm22_df)

    lm22_genes <- lm22_df %>% dplyr::select(`Gene symbol`) %>% flatten_chr
    lm22_rel_genes <- intersect(rownames(expression_data), lm22_genes)
    print(
      paste(
        length(lm22_rel_genes), "out of", length(lm22_genes),
        "LM22 genes are present in the expression data"
      )
    )

    # Filter the matrix down to LM22 genes
    expression_data_lm22 <- expression_data[lm22_rel_genes, ]
    head(expression_data_lm22)
    dim(expression_data_lm22)

    # Filter out genes where we have almost no data (i.e. top 10%), and write out as
    # an input file for CIBERSORT.
    cibersort_input <- glue("{tmpdir}/cibersort-input.tsv")
    low_expression_threshold <- 1
    test <- expression_data_lm22 %>%
        data.frame() %>%
        tibble::rownames_to_column("Gene_symbols") %>%
        mutate(low_cnt=rowSums(.[-1] < low_expression_threshold)) %>%
        filter(low_cnt < quantile(low_cnt, .90)) %>%  # FIXME: Changed from `<` to `<=`...didn't work when low_cnt was 0 for most/all.
        dplyr::select(-low_cnt) %>%
        write_tsv(cibersort_input) %>%
        dim() # +1 column since we added the indices back to table for convenience

    # Run CIIBERSORT
    library(Rserve)
    Rserve(args="--no-save")
    shell(
        command="java",
        glue(
         "-Xmx10g -Xms3g \\
          -jar {cibersort_home_dir}/CIBERSORT.jar \\
          -M {cibersort_input} -B {lm22_path} \\
          > {tmpdir}/cibersort-output.tsv
          2> {tmpdir}/cibersort.err.log"
        )  # by default results are printed to stdout
    )
    shell(command="pkill", "-9 Rserve")  # no need to be graceful here

    # Read in results
    cibersort <- read_delim(glue("{tmpdir}/cibersort-output.tsv"), delim="\t", comment=">", trim_ws=TRUE)
    head(cibersort)

    # The CIBERSORT output has an extra tab at the end of the headers row, so it adds
    # in this extra column `X27` with no data. The output also contains a column called
    # `Column` that just numbers each row. Remove both of these here.
    cibersort.df <- cibersort %>%
                        data.frame %>%
                        dplyr::select(-`X27`, -`Column`)
    sampleNames <- colnames(expression_data_lm22)
    row.names(cibersort.df) <- sampleNames
    
    cibersort.df %>%
        tibble::rownames_to_column("Sample Name") %>%
        write_tsv(glue("{tmpdir}/cibersort-output.tsv"))

    cibersort.df
}

# %%
run_estimate <- function(expression_data, tmpdir) {
    # Convert our expression matrix into GCT format and save it to be 
    # used by ESTIMATE
    estimate_input <- glue("{tmpdir}/estimate-input.gct")

    outputGCT(expression_data, estimate_input)

    # Run ESTIMATE and save the results into another GCT file
    estimate_output <- glue('{tmpdir}/estimate-output.gct')
    estimateScore(estimate_input, output.ds=estimate_output, platform="illumina")

    # Load them back and return
    estimate_df <- read_tsv(estimate_output, comment="#", skip=1) %>%
                        dplyr::select(-`NAME`) %>%
                        as.data.frame
    estimate_df %>%
        column_to_rownames("Description")
}

# %%
run_xcell <- function(expression_data, tmpdir) {
    xcell_res <- xCellAnalysis(expression_data,
                               save.raw=TRUE,  # This produces a second output file with untransformed scores.
                               file.name=glue('{tmpdir}/xcell-output'))
    
    xcell_output <- glue('{tmpdir}/xcell-output.tsv')
    xcell_res %>%
        as.data.frame %>%
        rownames_to_column("CellType") %>%
        write_tsv(xcell_output)
    xcell_res
}

# %%
run_mcpcounter <- function(expression_data, tmpdir) {
    mcp_res <- MCPcounter.estimate(expression_data, featuresType="HUGO_symbols")
    mcp_output <- glue("{tmpdir}/mcpcounter-output.tsv")
    mcp_res %>%
        as.data.frame %>%
        rownames_to_column("CellType") %>%
        write_tsv(mcp_output)
    mcp_res
}

# %%
tmpdir <- "build"
expression_data <- get_expression_data(tmpdir)
head3(expression_data)
# run_cibersort(expression_data, tmpdir)
# run_estimate(expression_data %>% data.frame() %>% tibble::column_to_rownames('Gene_symbol'), tmpdir)
# run_estimate(expression_data, tmpdir)
# run_xcell(expression_data, tmpdir)
run_mcpcounter(expression_data, tmpdir)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Gene_symbol = col_character()
# )
# See spec(...) for full column specifications.
#      gerald.H5NKVBBXX.4.CGGCTATG.TATAGCCT gerald.H5NKVBBXX.4.CTGAAGCT.ATAGAGGC
# A1BG   160.2753                             29.19838
# A1CF   103.0000                              9.00387
# A2M  53163.7239                           6305.79310
#      gerald.H5NKVBBXX.4.TAATGCGC.ATAGAGGC gerald.H5NKVBBXX.4.TAATGCGC.TATAGCCT
# A1BG   89.983320                           172.5639
# A1CF    6.999996                           208.0000
# A2M  6032.217320                          2788.6935
#      gerald.H5NKVBBXX.4.TCTCGCGC.ATAGAGGC gerald.H5NKVBBXX.5.ATTACTCG.ATAGAGGC
# A1BG   118.00680                            365.7986
# A1CF    76.01059                            288.0374
# A2M  12548.85321                          14220.8857
#      gerald.H5NKVBBXX.5.ATTACTCG.CCTATCCT gerald.H5NKVBBXX.5.ATTACTCG.TATAGCCT
# A1BG   231.9847                             458.5096
# A1CF    16.0156                             261.2861
# A2M  52604.2210                           39731.8083
#      gerald.H5NKVBBXX.5.ATTCAGAA.ATAGAGGC gerald.H5NKVBBXX.5.CGCTCATT.ATAGAGGC
# A1BG   425.8787                            1176.1113
# A1CF   144.5596                             134.9335
# A2M  53494.5108                           20731.3946
#      ⋯ gerald.H5NKVBBXX.6.TCCGCGAA.ATAGAGGC
# A1BG ⋯   578.7028
# A1CF ⋯   166.0010
# A2M  ⋯ 55476.2603
#      gerald.H5NKVBBXX.6.TCCGCGAA.TATAGCCT gerald.H5NKVBBXX.6.TCTCGCGC.TATAGCCT
# A1BG 2938.4187                             133.3406
# A1CF  183.0124                             106.0640
# A2M  6677.8170                            7270.9104
#      gerald.H5NKVBBXX.7.ATTCAGAA.TATAGCCT gerald.H5NKVBBXX.7.CGCTCATT.TATAGCCT
# A1BG   449.5915                           1032.19420
# A1CF   125.0098                             15.00308
# A2M  85258.1091                           5215.15598
#      gerald.H5NKVBBXX.7.CTGAAGCT.TATAGCCT gerald.H5NKVBBXX.7.GAATTCGT.TATAGCCT
# A1BG  1121.0535                            1016.4681
# A1CF   130.5271                             298.9732
# A2M  20041.5642                           26814.7081
#      gerald.H5NKVBBXX.7.GAGATTCC.ATAGAGGC gerald.H5NKVBBXX.7.GAGATTCC.TATAGCCT
# A1BG   931.8012                             966.2057
# A1CF   222.0008                             273.0109
# A2M  25570.4671                           93369.1144
#      gerald.H5NKVBBXX.7.TCCGGAGA.CCTATCCT
# A1BG   300.1420
# A1CF   450.0056
# A2M  50277.6901
#                         gerald.H5NKVBBXX.4.CGGCTATG.TATAGCCT
# T cells                   258.03017
# CD8 T cells               128.41972
# Cytotoxic lymphocytes      41.58387
# NK cells                   24.13744
# B lineage                 257.07394
# Monocytic lineage         703.59358
# Myeloid dendritic cells   106.68688
# Neutrophils               659.49477
# Endothelial cells        1334.69317
# Fibroblasts             17104.38284
#                         gerald.H5NKVBBXX.4.CTGAAGCT.ATAGAGGC
# T cells                   42.369740
# CD8 T cells                4.993360
# Cytotoxic lymphocytes      6.529693
# NK cells                   5.088166
# B lineage                 50.423209
# Monocytic lineage         72.582399
# Myeloid dendritic cells   11.300008
# Neutrophils              105.116185
# Endothelial cells        159.916302
# Fibroblasts             1613.102243
#                         gerald.H5NKVBBXX.4.TAATGCGC.ATAGAGGC
# T cells                    63.672543
# CD8 T cells                20.999990
# Cytotoxic lymphocytes      20.730223
# NK cells                    5.988858
# B lineage                  51.173434
# Monocytic lineage         178.045856
# Myeloid dendritic cells    33.141178
# Neutrophils               101.384593
# Endothelial cells         322.561283
# Fibroblasts             23874.126032
#                         gerald.H5NKVBBXX.4.TAATGCGC.TATAGCCT
# T cells                  158.37900
# CD8 T cells              229.00000
# Cytotoxic lymphocytes     79.68378
# NK cells                  25.92171
# B lineage                108.10623
# Monocytic lineage        281.70732
# Myeloid dendritic cells   86.77015
# Neutrophils              677.08543
# Endothelial cells        340.47808
# Fibroblasts             4953.25464
#                         gerald.H5NKVBBXX.4.TCTCGCGC.ATAGAGGC
# T cells                  565.26341
# CD8 T cells              152.95100
# Cytotoxic lymphocytes     37.48210
# NK cells                  35.52820
# B lineage                120.98494
# Monocytic lineage        398.72884
# Myeloid dendritic cells   51.25082
# Neutrophils             1313.08040
# Endothelial cells       2242.32781
# Fibroblasts             8049.40722
#                         gerald.H5NKVBBXX.5.ATTACTCG.ATAGAGGC
# T cells                   383.62473
# CD8 T cells                25.99999
# Cytotoxic lymphocytes      40.49905
# NK cells                   11.17112
# B lineage                 160.49692
# Monocytic lineage         577.25072
# Myeloid dendritic cells    33.80558
# Neutrophils              1014.35809
# Endothelial cells        1609.33176
# Fibroblasts             16290.57799
#                         gerald.H5NKVBBXX.5.ATTACTCG.CCTATCCT
# T cells                    127.12544
# CD8 T cells                  0.00000
# Cytotoxic lymphocytes       17.29510
# NK cells                    22.66280
# B lineage                   65.32364
# Monocytic lineage          631.06060
# Myeloid dendritic cells     43.10429
# Neutrophils                506.61231
# Endothelial cells         1947.32990
# Fibroblasts             113795.81921
#                         gerald.H5NKVBBXX.5.ATTACTCG.TATAGCCT
# T cells                    512.77558
# CD8 T cells                329.00000
# Cytotoxic lymphocytes       99.89621
# NK cells                    73.33534
# B lineage                  503.08778
# Monocytic lineage         1181.59918
# Myeloid dendritic cells    230.01630
# Neutrophils               1136.58230
# Endothelial cells         2005.12118
# Fibroblasts             121623.82084
#                         gerald.H5NKVBBXX.5.ATTCAGAA.ATAGAGGC
# T cells                   343.97235
# CD8 T cells               160.25034
# Cytotoxic lymphocytes      69.86164
# NK cells                   49.77071
# B lineage                 308.02022
# Monocytic lineage        1053.61526
# Myeloid dendritic cells   222.03981
# Neutrophils              1142.73634
# Endothelial cells        2133.78842
# Fibroblasts             51247.94948
#                         gerald.H5NKVBBXX.5.CGCTCATT.ATAGAGGC ⋯
# T cells                  1190.88239                          ⋯
# CD8 T cells               232.92266                          ⋯
# Cytotoxic lymphocytes     210.39135                          ⋯
# NK cells                   56.60621                          ⋯
# B lineage                3976.57277                          ⋯
# Monocytic lineage        1570.90034                          ⋯
# Myeloid dendritic cells   199.72563                          ⋯
# Neutrophils              1454.25332                          ⋯
# Endothelial cells        2058.15472                          ⋯
# Fibroblasts             57410.96679                          ⋯
#                         gerald.H5NKVBBXX.6.TCCGCGAA.ATAGAGGC
# T cells                   241.35106
# CD8 T cells               163.30978
# Cytotoxic lymphocytes      66.89683
# NK cells                   32.91442
# B lineage                 181.71993
# Monocytic lineage        1120.10784
# Myeloid dendritic cells    71.56706
# Neutrophils              1136.78921
# Endothelial cells        1559.55271
# Fibroblasts             70305.38662
#                         gerald.H5NKVBBXX.6.TCCGCGAA.TATAGCCT
# T cells                   290.10382
# CD8 T cells               120.42475
# Cytotoxic lymphocytes     164.70929
# NK cells                   28.05641
# B lineage                 300.57121
# Monocytic lineage         692.87658
# Myeloid dendritic cells    79.20291
# Neutrophils              1131.13038
# Endothelial cells        1550.30196
# Fibroblasts             48624.88255
#                         gerald.H5NKVBBXX.6.TCTCGCGC.TATAGCCT
# T cells                  252.31332
# CD8 T cells              178.99980
# Cytotoxic lymphocytes     12.41965
# NK cells                  39.41052
# B lineage                130.78001
# Monocytic lineage        233.31712
# Myeloid dendritic cells   90.80000
# Neutrophils             1130.55919
# Endothelial cells       1034.04410
# Fibroblasts             7106.69414
#                         gerald.H5NKVBBXX.7.ATTCAGAA.TATAGCCT
# T cells                   240.35471
# CD8 T cells               104.09030
# Cytotoxic lymphocytes      39.87661
# NK cells                   55.03378
# B lineage                 204.85755
# Monocytic lineage        1012.37858
# Myeloid dendritic cells   128.79609
# Neutrophils              1140.68556
# Endothelial cells        1806.33275
# Fibroblasts             47844.09478
#                         gerald.H5NKVBBXX.7.CGCTCATT.TATAGCCT
# T cells                   293.85645
# CD8 T cells               340.22100
# Cytotoxic lymphocytes      81.40726
# NK cells                   15.93965
# B lineage                  61.03991
# Monocytic lineage         573.92779
# Myeloid dendritic cells    81.20010
# Neutrophils               719.51374
# Endothelial cells         807.04314
# Fibroblasts             46531.59456
#                         gerald.H5NKVBBXX.7.CTGAAGCT.TATAGCCT
# T cells                   369.86630
# CD8 T cells                76.96831
# Cytotoxic lymphocytes      89.78837
# NK cells                   99.74961
# B lineage                 790.23599
# Monocytic lineage        2873.39554
# Myeloid dendritic cells   161.10536
# Neutrophils              3151.74898
# Endothelial cells        1039.17906
# Fibroblasts             92087.02762
#                         gerald.H5NKVBBXX.7.GAATTCGT.TATAGCCT
# T cells                   868.87871
# CD8 T cells               395.32420
# Cytotoxic lymphocytes     131.80791
# NK cells                   81.88579
# B lineage                1065.91892
# Monocytic lineage        1851.19389
# Myeloid dendritic cells   340.64179
# Neutrophils              1002.71661
# Endothelial cells        1719.24469
# Fibroblasts             16565.82265
#                         gerald.H5NKVBBXX.7.GAGATTCC.ATAGAGGC
# T cells                   503.36622
# CD8 T cells               155.34520
# Cytotoxic lymphocytes      75.51874
# NK cells                   59.23897
# B lineage                 178.03942
# Monocytic lineage        1001.83503
# Myeloid dendritic cells   136.37353
# Neutrophils              1140.13750
# Endothelial cells        1624.81512
# Fibroblasts             98849.93688
#                         gerald.H5NKVBBXX.7.GAGATTCC.TATAGCCT
# T cells                    423.55900
# CD8 T cells                154.45260
# Cytotoxic lymphocytes       74.95644
# NK cells                    83.26667
# B lineage                  510.20766
# Monocytic lineage         1750.94157
# Myeloid dendritic cells    173.94844
# Neutrophils               1048.61663
# Endothelial cells         2771.81321
# Fibroblasts             131182.85049
#                         gerald.H5NKVBBXX.7.TCCGGAGA.CCTATCCT
# T cells                   968.3559
# CD8 T cells               537.8959
# Cytotoxic lymphocytes     291.7428
# NK cells                  116.5634
# B lineage                 408.2572
# Monocytic lineage        2951.6945
# Myeloid dendritic cells   410.6533
# Neutrophils              2333.4675
# Endothelial cells        2860.8877
# Fibroblasts             26317.6356
